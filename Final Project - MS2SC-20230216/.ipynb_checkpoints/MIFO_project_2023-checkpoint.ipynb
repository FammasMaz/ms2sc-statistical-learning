# %% [markdown]
# # Modélisation des incertitude, mécanique probabiliste 2021-2022

# %% [markdown]
# ## Final Project
#
# ### Outline

# %% [markdown]
# The final project consists into _conceive_ and _train_ an efficient metamodel to predict the mechanical behaviour of the ten-bar truss problem [1]
#
# ![Truss structure](truss_structure.png)

# %% [markdown]
# The mechanical properties of the ten-bar truss problems are affected by high uncertainty. In particular, a few key parameters have to be considered in this project[1]:

# %% [markdown]
# ![Table of random mechanical properties [1].](table_truss_random.png)

# %% [markdown]
# where :
#
# - $A_1$: the cross-section areas of the horizontal members
# - $A_2$: the cross-section areas of the vertical members
# - $A_3$: the cross-section areas of the diagonal members
# - $E$: Young's Modulus
# - $L$: truss lengths
# - $P$: load acting at the joints

# %% [markdown]
# The __quantity of interest__ (__QoI__) is the tip displacement $d$ and the allowable displacement at node 2, whose theoretical expression reads (Equation 1):

# %% [markdown]
# $$d = \frac{PL}{A_1 A_3 E D_T}\left[4 \sqrt{2}A_1^3 \left(24 A_2^2 + A_3^2 \right)+A_3^3 \left(7 A_1^2 + 26 A_2^2 \right)+4 A_1 A_2 A_3 \left\lbrace \left( 20 A_1^2 + 76 A_1 A_2 + 10 A_3^2 \right) + \sqrt{2} A_3 \left( 25 A_1 + 29 A_2 \right) \right\rbrace\right]$$

# %% [markdown]
# where: $$D_T = 4 A_2^2 \left( 8 A_1^2 + A_3^2 \right) + 4 \sqrt{2} A_1 A_2 A_3 \left( 3 A_1 + 4 A_2 \right) + A_1 A_3^2 \left( A_1 + 6 A_2 \right)$$

# %% [markdown]
# The reliability is evaluated for __Limit State Function__
# with respect to the displacement at node 2 as following:
#
#
#
# $$g = d_{allow}-d$$
#
#
# with the following allowed displacement values:

# %% [markdown]
# __Table 2__

# %% [markdown]
# ![Table of allowed maximum displacement at node 2 [1].](dallow.png)

# %% [markdown]
# ## Task 1 - Generate the dataset [T1]
#
# Considering Table 1, perform a __Design of Experiment (DoE)__ by producing a __Learning DataBase (LDB)__ for suitable metamodelling. To this end, use the [__Direct MonteCarlo Simulation technique (DMCS)__](https://en.wikipedia.org/wiki/Direct_simulation_Monte_Carlo) by considering the following alternative scenarios:
#
# - T1.1 the variables in Table 1 are all independent random variables (__LDB1__)
# - T1.2 the variables in Table 1 are all independent but two $A_1$, $L$, with correlation coefficients $R_{A_1,L}$=0.2  (__LDB2__)
#
# - __Hint 1:__ For this task, you can neglect inertial effects and consider the problem as quasi-static
#
# - __Hint 2:__ Generate independent normal random variables $\mathcal{N}(\mathbf{0},\mathbf{I})$
#
# - __Hint 3:__ Assemble the correlation matrix $\mathbf{R}$
#
# - __Hint 4:__ Compute the diagonal correlation matrix and associated eigenvectors
#
# - __Hint 5:__ Assemble the correlated Gaussian random field
#
# - __Hint 6:__ If the random field follows a non-gaussian marginal probability distribution, use the Rosenblatt transform

# %%
# Imports
import requests
import numpy as np
import scipy
import pandas as pd
import sklearn as skl

import scikitplot as skplt
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import datasets
from sklearn.metrics import mean_squared_error as skmse
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import axes3d, Axes3D
from matplotlib.colors import ListedColormap

# %matplotlib inline

# %%
# Dataset parameters
# Mean and Standard Deviations

mu_A1 = 7.5e-3
mu_A2 = 1.5e-3
mu_A3 = 5.0e-3
mu_E = 70
mu_L = 9
mu_P = 350
sigma_A1 = 0.1
sigma_A2 = 0.1
sigma_A3 = 0.1
sigma_E = 0.05
sigma_L = 0.05
sigma_P = 0.1

# Mean and Sigma Arrays for LogNormal Distribution: A1, L,A2, A3, E
mu = np.array([mu_A1, mu_L, mu_A2, mu_A3, mu_E])
sigma = np.array([sigma_A1, sigma_L, sigma_A2, sigma_A3, sigma_E])

# Mean and Sigma Arrays for Gumbell Distributions: P
mug = np.array([mu_P])
sigmag = np.array([sigma_P])

# %%
# Functions for operations throughout notebook

def D_T(X):
    '''Function for Calculation for D_t
    Input: Random Matrix of (n, p) size, with n=No. of Variables, p=No. of Simulations
           Arrangement Considered (A_1, L, A_2, A_3, E, P)
    Output: displacement d'''
    
    [A_1, L, A_2, A_3, E, P] = X
    E = E*1e9
    P = P*1e3
    Dt = 4*(A_2**2)*((8*A_1**2) + (A_3**2)) + 4*2**0.5*A_1*A_2*A_3*(3*A_1 + 4*A_2) + A_1*A_3**2*(A_1 + 6*A_2)
    return Dt
def dtest(X):
    '''Function for Calculation for displacement d
    Input: Random Matrix of (n, p) size, with n=No. of Variables, p=No. of Simulations
           Arrangement Considered (A_1, L, A_2, A_3, E, P)
    Output: displacement d'''
    
    [A_1, L, A_2, A_3, E, P] = X
    E = E*1e9
    P = P*1e3
    d = P*L/(A_1*A_3*E*D_T(X))*(4*2**0.5*A_1**3 * (24*A_2**2 + A_3**2)+A_3**3*(7*A_1**2 + 26*A_2**2)+4*A_1*A_2*A_3*((20*A_1**2 + 76*A_1*A_2 + 10*A_3**2) + 2**0.5*A_3*(25*A_1 + 29*A_2)))
    return d

def limit(d, dallow):
    '''Limit function g = dallow - d
    Input: Limiting displacement critiera: dallow
    Output: Limit function value g'''
    return dallow - d
def Xc_gen(p, cor = False, alpha = 0.95, rho = 0.2, dallow=0.1, mu=mu, sigma=sigma, mug=mug, sigmag=sigmag):
    '''Data generator based on two distribution types: LogNormal and Gumbel
    Input:  p=No. of Simulations
            cor=Bool to turn on the correlation in data (default=False)
            alpha=Confidence interval (default=0.95)
            rho=Correlation parameter (default=0.2)
            dallow=Limiting displacement (default=0.1)
            mu=Array of mean values for parameters following LogNormal Dist.
            sigma=Array of S.D. for parameters following LogNormal Dist
            mug=Array of mean values for parameters following Gumbell Dist.
            sigma=Array of S.D. for parameters following Gumbell Dist
    Output: Xc=Dataset following of size=(n=no.of var., p=no. of sim.)
            pf=Probability of failure
            m_d=Mean displacement
            s_d=Mean sigma
            d=Displacement size=(1, p=no. of simulations)'''
    
    #LogNormal Distribution
    n = mu.shape[0]
    sigmaln = np.log(1+(sigma**2))
    sigmalnd = np.diag(sigmaln)
    mus = np.log(mu) - 0.5*(sigmaln)
    mud = np.vstack([mus]*p).T

    # Gumbell
    mug=mug.T
    ng = mug.shape[0]
    sigmag = np.array([sigma_P*mu_P])
    alphas = (6**0.5)*sigmag/np.pi
    s0 = mug - 0.577216*alphas
    
    S = np.random.normal(0,1,(n,p))
    if cor == True:
        # RosenBlatt Transformation
        R = np.array([[1, rho], [rho, 1]])
        eigval, eigvec = np.linalg.eig(R)
        S[0:2, :] = eigvec@np.sqrt(np.diag(eigval))@S[0:2,:]

    Ug = np.random.uniform(0,1,(ng,p))
    Sgs = s0 - alphas * np.log(-np.log(Ug))

    X = np.exp(np.sqrt(sigmalnd)@S + mud)

    Xc = np.vstack((X, Sgs))
    [A_1, L, A_2, A_3, E, P] = Xc
    d = dtest(Xc)
    g = limit(d, dallow)
    test = g <= 0 # Criteria
    test = test.astype(int)
    dat = test.copy()
    m_d = 1/p * np.sum(d)
    s_d = np.sqrt(1/p * np.sum((d-m_d)**2))
    pf = 1/p * np.sum(dat)
    #m_low, m_up, s_low, s_up = confidence_interval(m_d, s_d, alpha, p)
    return Xc, pf, m_d, s_d, d

def confidence_interval(m, s, alpha, N) :
    # Interval for mean
    t_low = stats.t.cdf(1-alpha/2, N-1)
    t_up = stats.t.cdf(1-alpha/2, N+1)
    m_low = m - t_low * s/np.sqrt(N)
    m_up = m + t_up * s/np.sqrt(N)
    
    # Interval for standard deviation
    chi_low = stats.chi2.cdf(1-alpha/2, N-1)
    chi_up = stats.chi2.cdf(alpha/2, N-1)
    s_low = np.sqrt((N-1)*s**2/chi_low**2)
    s_up = np.sqrt((N-1)*s**2/chi_up**2)  

    return m_low, m_up, s_low, s_up

# %%
# SCATTER AND HISTORGRAMS
# =======================================================
# TASK 1.1 Uncorrelated Data
X, _, _, _,d  = Xc_gen(5000, cor=False) # Generate data
X = np.vstack((X, d)) # Stack X and d
dX = pd.DataFrame(X.T, columns = ['A1', 'L', 'A2', 'A3', 'E', 'P', 'd'])
# Create Dataframe and Plot Scatter and Histogram in Data
pd.plotting.scatter_matrix(dX, diagonal='hist')
plt.suptitle(f'Scatter Plot and Histograms for Uncorrelated Data')
plt.savefig('scatter_uncorr.png', dpi=300)
plt.show()

# TASK 1.2: Uncorrelated Data with rho = 0.8 (rho increased to see effect clearer)
Xc, _, _, _,d  = Xc_gen(5000, cor=True, rho = 0.8) # Generate data
Xc = np.vstack((Xc, d)) # Stack X and d
# Create Dataframe and Plot Scatter and Histogram in Data
dXc = pd.DataFrame(Xc.T, columns = ['A1', 'L', 'A2', 'A3', 'E', 'P', 'd'])
axes = pd.plotting.scatter_matrix(dXc, diagonal='hist')
plt.suptitle(r'Scatter Plot and Histograms for Correlated Data ($\rho = 0.8$)')
plt.savefig('scatter_rho08.png', dpi=300)
plt.show()

print(fr'''We can see that except for P, all variables follow
LogNormal Dist., P follows Gumbel
Also with $\rho=0.8$ we can see a correlation between A1 and L''')
# Out:
# We can see that except for P, all variables follow
# LogNormal Dist., P follows Gumbel
# Also with $\rho=0.8$ we can see a correlation between A1 and L

# %%
# MONTE-CARLO VISUALIZATION
# ========================================
# TASK 1.1: Uncorrelated data
Np = 5000 # No. of Simulations
N = np.arange(1, Np, 1) # For iteration

# Initializations
pfA = np.zeros(N.shape) 
m_dA = np.zeros(N.shape)

# Range of d_allow for
dAllow=[0.1, 0.105, 0.11, 0.115, 0.12]

# Looping over N and d_allow and plotting the cases on the same plot
for j in range(len(dAllow)):
    for i in range(len(N)):
        Xc, xpf, m_d, s_d, d = Xc_gen(N[i], cor=False, dallow=dAllow[j])
        pfA[i] = xpf
        m_dA[i] = m_d
    plt.figure(1)
    pfAm = np.mean(pfA[int(Np/2):Np])
    label = fr'$d_{{allow}} = {dAllow[j]:.3f} $ m, pf = {pfAm*100:.2f}%'
    plt.plot(pfA, label=label)
    plt.title(fr'Uncor. Case: Probability of Failure for Different $d_{{allow}}$')
    plt.xlabel('Number of Samples')
    plt.ylabel('Prob. of Failure')
    plt.legend()
    
    plt.figure(2)
    label = fr'$d_{{allow}}$ = {dAllow[j]}'
    plt.plot(m_dA, label=label)
    plt.title(fr'Uncor. Case: Mean Displacement $d_{{mean}}$: {np.mean(m_dA[int(Np/2):Np]):.4f} m')
    plt.xlabel('Number of Samples')
    plt.ylabel('d (m)')
    plt.legend()

plt.figure(1)
plt.savefig('pfUncor', dpi=300)
plt.figure(2)
plt.savefig('m_dUncor', dpi=300)

# %%
# MONTE-CARLO VISUALIZATION
# ========================================
# TASK 1.2: Correlated data
Np = 5000 # No. of Simulations
N = np.arange(1, Np, 1) # For iteration

# Initializations
pfA = np.zeros(N.shape) 
m_dA = np.zeros(N.shape)

# Range of d_allow for
dAllow=[0.1, 0.105, 0.11, 0.115, 0.12]

# Looping over N and d_allow and plotting the cases on the same plot
for j in range(len(dAllow)):
    for i in range(len(N)):
        Xc, xpf, m_d, s_d, d = Xc_gen(N[i], cor=True, dallow=dAllow[j])
        pfA[i] = xpf
        m_dA[i] = m_d
    plt.figure(1)
    pfAm = np.mean(pfA[int(Np/2):Np])
    label = fr'$d_{{allow}} = {dAllow[j]:.3f} $ m, pf = {pfAm*100:.2f}%'
    plt.plot(pfA, label=label)
    plt.title(fr'Corr. Case: Probability of Failure for Different $d_{{allow}}$')
    plt.xlabel('Number of Samples')
    plt.ylabel('Prob. of Failure')
    plt.legend()
    
    plt.figure(2)
    label = fr'$d_{{allow}}$ = {dAllow[j]}'
    plt.plot(m_dA, label=label)
    plt.title(fr'Corr. Case: Mean Displacement $d_{{mean}}$: {np.mean(m_dA[int(Np/2):Np]):.4f} m')
    plt.xlabel('Number of Samples')
    plt.ylabel('d (m)')
    plt.legend()

plt.figure(1)
plt.savefig('pfCor', dpi=300)
plt.figure(2)
plt.savefig('m_dCor', dpi=300)

# %% [markdown]
# ## Task 2 - Basic statistics on the datasets [T2]
#
# - T2.1 Compute the Pearson's correlation between each variable, for each dataset  (__LDB1__,  __LDB2__)
# - T2.2 Do you notice any correlation between each variable at different time steps?
#
# Hint : use `pandas`

# %%
# TASK 2.1
# PEARSON CORRELATION FOR BOTH CASES
# ========================================
# Uncorrelated Data
Xc, _, _, _, d = Xc_gen(5000) # Generate Uncorrelated Data
Xc = np.vstack((Xc,d)) # Stack Xc and d
[A_1, L, A_2, A_3, E, P, d] = Xc # Get the Variables as Invidual Arrays
columns = ['A_1', 'L', 'A_2', 'A_3', 'E', 'P', 'D']
Xc = Xc.T
dfX = pd.DataFrame(Xc, columns = columns)
cor_mat = dfX.corr(method='pearson') # Calculate correlation
print('Correlation Matrix for Uncorrelated Data:\n')
print(cor_mat)
print('\n================================================\n')

# Correlated Data
Xcc, _, _, _, dc = Xc_gen(5000, cor=True) # Generate Uncorrelated Data
Xcc = np.vstack((Xcc,dc)) # Stack Xc and d
[A_1, L, A_2, A_3, E, P, d] = Xcc # Get the Variables as Invidual Arrays
Xcc = Xcc.T
dfXc = pd.DataFrame(Xcc, columns = columns)
cor_matc = dfXc.corr(method='pearson') # Calculate correlation
print('Correlation Matrix for Correlated Data:\n')
print(cor_matc)
print('\n================================================')
fr'''We can see correlation of 2, between the A_1 and L which is corresponding to the one that we set as $\rho$ = 2'''
# Out:
# Correlation Matrix for Uncorrelated Data:
#
#           A_1         L       A_2       A_3         E         P         D
# A_1  1.000000 -0.015401 -0.012175  0.000626  0.003658  0.008574 -0.340450
# L   -0.015401  1.000000  0.004058  0.006824  0.001834  0.013950  0.364242
# A_2 -0.012175  0.004058  1.000000 -0.018763 -0.021919  0.002338 -0.000435
# A_3  0.000626  0.006824 -0.018763  1.000000  0.002835 -0.000680 -0.341867
# E    0.003658  0.001834 -0.021919  0.002835  1.000000 -0.010420 -0.356897
# P    0.008574  0.013950  0.002338 -0.000680 -0.010420  1.000000  0.711880
# D   -0.340450  0.364242 -0.000435 -0.341867 -0.356897  0.711880  1.000000
#
# ...
#
# Correlation Matrix for Correlated Data:
#
#           A_1         L       A_2       A_3         E         P         D
# A_1  1.000000  0.208200  0.001508 -0.019886 -0.018376  0.000141 -0.259386
# L    0.208200  1.000000 -0.008894 -0.003889 -0.005104  0.002778  0.297434
# ...

# %% [markdown]
# ## Task 3 - Compute the PCA [T3]
#
# - T3.1 Perform a PCA analysis on each dataset (__LDB1__,  __LDB2__) to obtain a reduced number of Principal Components to describe the structural response
#
# - T3.2 How is the PCA affected in time, given that $P(t)$ is a random field with triangular auto-correlation (T1.3)?
#
# Hint: use the package `sklearn.decomposition.PCA`

# %%
# TASK 3.1
# PCA COMPUTATION FOR BOTH CASES
# ============================================
# Correlated Data
Xc, _, _, _, d = Xc_gen(5000, cor = True) # Generate correlated data
Xc = np.vstack((Xc,d)) # Stack Xc and d
[A_1, L, A_2, A_3, E, P, d] = Xc # Get individual variables
columns = ['A_1', 'L', 'A_2', 'A_3', 'E', 'P', 'd']
Xc = Xc.T
dfX = pd.DataFrame(Xc, columns = columns)

#PCA Computation
pca = PCA(n_components=6)
pca_df = pca.fit_transform(dfX)

# ==================================================================
# Uncorrelated Data
Xc, _, _, _, d = Xc_gen(5000, cor = False) # Generate correlated data
Xc = np.vstack((Xc,d)) # Stack Xc and d
[A_1, L, A_2, A_3, E, P, d] = Xc # Get individual variables
columns = ['A_1', 'L', 'A_2', 'A_3', 'E', 'P', 'd']
Xc = Xc.T
dfX = pd.DataFrame(Xc, columns = columns)

#PCA Computation
pca2 = PCA(n_components=6)
pca_df2 = pca2.fit_transform(dfX)

# %%
# VISUALIZATIONS AFTER PERFORMING PCA

# Plot the convergence of explained variance ratio
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.plot(np.cumsum(pca2.explained_variance_ratio_), marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance from the Data')
plt.legend(['Correlated', 'Uncorrelated'])
plt.savefig('cumulative_variance')
plt.show()

# Plot the eigenvalues of explained variance ratio
plt.plot(range(1,7), pca.explained_variance_, marker='o')
plt.plot(range(1,7), pca2.explained_variance_, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Eigenvalue')
plt.title('Eigenvalues from the Data')
plt.legend(['Correlated', 'Uncorrelated'])
plt.savefig('eigenvalues')
plt.show()

# Plot the coefficients of correlation between the PCA component and original dataset
# The plots are for PCA Component 1, 2 and 3 respectively
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(10, 8))
for i in range(3):
    ax[i].plot(pca.components_[i], 'bo-')
    ax[i].plot(pca2.components_[i], 'ro-')
    ax[i].set_xticks(range(7))
    ax[i].set_xticklabels(columns)
    ax[i].set_ylabel('Correspondence')
    ax[i].legend(['Correlated', 'Uncorrelated'])
plt.suptitle(r'Principal Components 1, 2, 3 Correspondence with Original Variables')
plt.savefig('loadings_pca', dpi=300)
plt.tight_layout()
plt.show()

# %%
# BIPLOTS FOR UNCORRELATED DATA
plt.scatter(pca_df2[:, 0], pca_df2[:, 1], alpha = 0.3)
colors = ['r', 'g', 'b', 'c', 'y', 'm']
for i in range(len(pca2.components_)): 
    eigV = pca2.components_[i]
    # The arrows here are scaled by the eigenvalues
    plt.arrow(0, 0, eigV[0], eigV[1],color = colors[i], head_width=2)
plt.xlabel('PC1 with ratio {:.2f}'.format(pca2.explained_variance_ratio_[0]))
plt.ylabel('PC2 with ratio {:.2f}'.format(pca2.explained_variance_ratio_[1]))
eig = [f'Component{i+1}' for i in range(len(pca2.components_))]
eig = ['Data'] + eig
plt.legend(eig)
plt.title('Biplot: Principal Components Uncorrelated Data')
plt.savefig('uncorBiplot')
plt.show()

# %%
# BIPLOTS FOR Correlated DATA
plt.scatter(pca_df[:, 0], pca_df[:, 1], alpha = 0.3)
colors = ['r', 'g', 'b', 'c', 'y', 'm']
for i in range(len(pca.components_)): 
    eigV = pca.components_[i]
    # Arrows scaled by the eigevectors
    plt.arrow(0, 0, eigV[0], eigV[1],color = colors[i], head_width=2)
plt.xlabel('PC1 with ratio {:.2f}'.format(pca.explained_variance_ratio_[0]))
plt.ylabel('PC2 with ratio {:.2f}'.format(pca.explained_variance_ratio_[1]))
eig = [f'Component{i}' for i in range(len(pca.components_))]
eig = ['Data'] + eig
plt.legend(eig)
plt.title('Biplot: Two principal Components for Correlated Data')
plt.savefig('corBiplot')
plt.show()

# %% [markdown]
# ## Task 4 - Design a meta-model [T4]
#
# - T4.1 Referring to T1.3, use the generated LDBs (i.e. the collection $\mathcal{S}:=\left\lbrace \mathbf{X}^{(t)},y^{(t)}\right\rbrace_{t=1,...,N}$ with $\mathbf{X}=\left[A_1,A_2,A_3,E,L,P\right]^T$ and $y=d$, computed via Equation 1) to conceive a metamodel $\tilde{y}=m(\mathbf{X})$ (ANN, others...) to predict the displacement of node 2 $d$.
#
# - T4.2 How is the predictive performance affected in time, given that $P(t)$ is a random field with triangular auto-correlation (T1.3)? Can you adapt your metamodel to all time-steps?
#
# - T4.3 Compute the following metrics :
# $$RMSE = \sqrt{\frac{1}{N}\sum_{t=1}^N\left(d^{(t)}-\tilde{d}^{(t)}\right)^2}$$
# $$R^2 = 1-\frac{\sum_{t=1}^N\left(d^{(t)}-\tilde{d}^{(t)}\right)^2}{\sum_{t=1}^N\left(d^{(t)}-\bar{d}\right)^2}$$
# $$\epsilon_m = \frac{1}{N}\sum_{t=1}^N 100\frac{\left(d^{(t)}-\tilde{d}^{(t)}\right)}{d^{(t)}}$$
#
# with $\bar{d} = \frac{1}{N}\sum_{t=1}^N \tilde{d}^{(t)}$

# %%
# TASK 4.1 and TASK 4.3
# METAMODEL CHOSEN AS AN ANN USING THE LIBRARY: SKLEARN WITH A REGRESSOR
# ========================================================================
# CORRELATED DATA 

# Generate Data
Np = 5000
Xc, _, _, _, d = Xc_gen(Np, cor = True)
Xc = Xc.T

# Split the dataset into train and test with 0.8 and 0.2 ration respec.
X_train, X_test, d_train, d_test = train_test_split(Xc, d, test_size=0.2)

# Scale both train and test datasets
X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# Create a model using MLP Regressor
# Parameters chosen here were chosen as a first trial and the idea was
# to grid search later
dmodel = MLPRegressor(hidden_layer_sizes=(256, 128, 64), 
                      activation = 'relu',
                      solver = 'adam',
                      learning_rate='adaptive',
                      alpha=0.01,
                      early_stopping=True,
                      max_iter = 1000,
                      warm_start = False)

# Fit the model on the data
dmodel.fit(X_train, d_train)
    
# Plot the loss curve
plt.plot(dmodel.loss_curve_) 
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Regression Loss Curve Correlated Data")
plt.savefig('Regression Loss Curve with Correlated Data', dpi=300)
plt.show()

# Prediction on the test set
d_pred = dmodel.predict(X_test)

# Coding R^2 metric and Comparing with R^2 from dmodel
R = 1 - ((np.sum((d_pred - d_test)**2))/((np.sum((d_test - np.mean(d_test))**2))))
print('Correlated Data\n=================================\n')
print("R-squared score:", R)
print("R-squared score from Sklearn Metrics:", dmodel.score(X_test, d_test))
print("R-squared score from Sklearn Metrics on Train Data:", dmodel.score(X_train, d_train))

# Coding RMSE metric and Comparing with R^2 from dmodel
mseM = np.sqrt(np.sum((d_pred-d_test)**2)/d_test.shape[0])
print("RMSE:", (mseM))
print("RMSE from Sklearn Metrics:", (np.sqrt(skmse(d_pred,d_test))))

# Coding the epsilon metric
e=(np.sum(100*(d_pred-d_test)/d_test))/d_test.shape[0]
print("epsilon:", (e))

# Visualize the dataset
pred=np.vstack((d_pred,d_test)).T
predDF=pd.DataFrame(pred , columns=['Predicted', 'Original'])
predDF.head()
# Out:
# Correlated Data
# ...
#
# R-squared score: 0.9954452492919619
# R-squared score from Sklearn Metrics: 0.9954452492919619
# R-squared score from Sklearn Metrics on Train Data: 0.9962240890783548
# RMSE: 0.0007557209003381558
# RMSE from Sklearn Metrics: 0.0007557209003381558
# epsilon: -0.1727388265590489
#    Predicted  Original
# 0   0.080337  0.080603
# 1   0.075289  0.076299
# 2   0.090289  0.090484
# 3   0.070357  0.070472
# 4   0.078053  0.078556

# %%
# Hyper Parameter tuning
# Defining the grid
hp_grid = {
    'hidden_layer_sizes': [(256,128,64), (512, 256, 128), (256, 128, 64, 32), (1000, 500)],
    'activation': ['tanh', 'relu'],
    'alpha': [0.0001, 0.01, 0.05, 0.005],
    'learning_rate': ['constant','adaptive'],
}

# Using GridSearchCV from SKLearn
resGrid = GridSearchCV(dmodel, hp_grid, n_jobs= -1, cv=5)
resGrid.fit(X_train, d_train)
y_pred_grid = resGrid.predict(X_test)

# %%
# Print the best parameters
print(grid.best_params_) 

# R^2 metric: Own vs Sklearn
R = 1 - ((np.sum((y_pred_grid - d_test)**2))/((np.sum((d_test - np.mean(d_test))**2))))
print("R-squared score:", R)
print("R-squared score from Sklearn Metrics:", grid.score(X_test, d_test))

# RMSE metric: Own vs Sklearn
mseM = np.sqrt(np.sum((y_pred_grid-d_test)**2)/d_test.shape[0])
print("RMSE:", (mseM))
print("RMSE from Sklearn Metrics:", (np.sqrt(skmse(y_pred_grid,d_test))))

# Epsilon metric: Own vs Sklearn
e=(np.sum(100*(y_pred_grid-d_test)/d_test))/d_test.shape[0]
print("epsilon:", (e))

pred=np.vstack((y_pred_grid,d_test)).T
predDF=pd.DataFrame(pred , columns=['Predicted', 'Original'])
predDF.head()
# Out:
# {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (1000, 500), 'learning_rate': 'adaptive'}
# R-squared score: 0.9976894924980603
# R-squared score from Sklearn Metrics: 0.9976894924980603
# RMSE: 0.0005382484883130868
# RMSE from Sklearn Metrics: 0.0005382484883130868
# epsilon: -0.3859970173850037
#    Predicted  Original
# 0   0.080162  0.080603
# 1   0.075919  0.076299
# 2   0.089889  0.090484
# 3   0.070677  0.070472
# 4   0.078240  0.078556

# %%
# TASK 4.1 and TASK 4.3
# METAMODEL CHOSEN AS AN ANN USING THE LIBRARY: SKLEARN WITH A REGRESSOR
# ========================================================================
# Uncorrelated DATA 

# Generate Data
Np = 5000
Xc, _, _, _, d = Xc_gen(Np, cor = False)
Xc = Xc.T

# Split the dataset into train and test with 0.8 and 0.2 ration respec.
X_train, X_test, d_train, d_test = train_test_split(Xc, d, test_size=0.2)

# Scale both train and test datasets
X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# Create a model using MLP Regressor
# Parameters chosen here were chosen as a first trial and the idea was
# to grid search later
dmodel = MLPRegressor(hidden_layer_sizes=(256, 128, 64), 
                      activation = 'relu',
                      solver = 'adam',
                      learning_rate='adaptive',
                      alpha=0.01,
                      early_stopping=True,
                      max_iter = 1000,
                      warm_start = False)

# Fit the model on the data
dmodel.fit(X_train, d_train)
    
# Plot the loss curve
plt.plot(dmodel.loss_curve_) 
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Regression Loss Curve Uncorrelated Data")
plt.savefig('Regression Loss Curve with Uncorrelated Data', dpi=300)
plt.show()

# Prediction on the test set
d_pred = dmodel.predict(X_test)

# Coding R^2 metric and Comparing with R^2 from dmodel
R = 1 - ((np.sum((d_pred - d_test)**2))/((np.sum((d_test - np.mean(d_test))**2))))
print('Uncorrelated Data\n=================================\n')
print("R-squared score:", R)
print("R-squared score from Sklearn Metrics:", dmodel.score(X_test, d_test))
print("R-squared score from Sklearn Metrics on Train Data:", dmodel.score(X_train, d_train))

# Coding RMSE metric and Comparing with R^2 from dmodel
mseM = np.sqrt(np.sum((d_pred-d_test)**2)/d_test.shape[0])
print("RMSE:", (mseM))
print("RMSE from Sklearn Metrics:", (np.sqrt(skmse(d_pred,d_test))))

# Coding the epsilon metric
e=(np.sum(100*(d_pred-d_test)/d_test))/d_test.shape[0]
print("epsilon:", (e))

# Visualize the dataset
pred=np.vstack((d_pred,d_test)).T
predDF=pd.DataFrame(pred , columns=['Predicted', 'Original'])
predDF.head()
# Out:
# Uncorrelated Data
# ...
#
# R-squared score: 0.9960033728097237
# R-squared score from Sklearn Metrics: 0.9960033728097237
# R-squared score from Sklearn Metrics on Train Data: 0.996420936516582
# RMSE: 0.0007395636342332756
# RMSE from Sklearn Metrics: 0.0007395636342332756
# epsilon: 0.23196910714683594
#    Predicted  Original
# 0   0.100319  0.099852
# 1   0.081089  0.080603
# 2   0.072986  0.073507
# 3   0.084626  0.084041
# 4   0.080388  0.080482

# %%
# Hyper Parameter tuning
# Defining the grid
hp_grid = {
    'hidden_layer_sizes': [(256,128,64), (512, 256, 128), (256, 128, 64, 32), (1000, 500)],
    'activation': ['tanh', 'relu'],
    'alpha': [0.0001, 0.01, 0.05, 0.005],
    'learning_rate': ['constant','adaptive'],
}

# Using GridSearchCV from SKLearn
resGrid = GridSearchCV(dmodel, hp_grid, n_jobs= -1, cv=5)
resGrid.fit(X_train, d_train)
y_pred_grid = resGrid.predict(X_test)

# %%
# Print the best parameters
print(grid.best_params_) 

# R^2 metric: Own vs Sklearn
R = 1 - ((np.sum((y_pred_grid - d_test)**2))/((np.sum((d_test - np.mean(d_test))**2))))
print("R-squared score:", R)
print("R-squared score from Sklearn Metrics:", grid.score(X_test, d_test))

# RMSE metric: Own vs Sklearn
mseM = np.sqrt(np.sum((y_pred_grid-d_test)**2)/d_test.shape[0])
print("RMSE:", (mseM))
print("RMSE from Sklearn Metrics:", (np.sqrt(skmse(y_pred_grid,d_test))))

# Epsilon metric: Own vs Sklearn
e=(np.sum(100*(y_pred_grid-d_test)/d_test))/d_test.shape[0]
print("epsilon:", (e))

pred=np.vstack((y_pred_grid,d_test)).T
predDF=pd.DataFrame(pred , columns=['Predicted', 'Original'])
predDF.head()
# Out:
# {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (1000, 500), 'learning_rate': 'adaptive'}
# R-squared score: 0.9991616867548785
# R-squared score from Sklearn Metrics: 0.9991616867548785
# RMSE: 0.0003387130211432493
# RMSE from Sklearn Metrics: 0.0003387130211432493
# epsilon: 0.21271846804989794
#    Predicted  Original
# 0   0.100124  0.099852
# 1   0.080929  0.080603
# 2   0.074062  0.073507
# 3   0.084385  0.084041
# 4   0.080452  0.080482

# %% [markdown]
# ## REFERENCES
#
# [1] Roy, A. & Chakraborty, S. _Support vector regression based metamodel by sequential adaptive sampling for reliability analysis of structures_, Reliability Engineering & System Safety 200, Elsevier, 106948, 2020 .
